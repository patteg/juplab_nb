# %%
>>> from newspaper import Article

>>> url = 'http://www.cbc.ca/news/world/trump-syria-strikes-chemical-weapons-1.4620005'
>>> article = Article(url)

# %%
>>> article.download()

>>> article.html

# %%
article.parse()

# %%
article.authors
# Out:
# ['Thomson Reuters']

# %%
article.publish_date

# %%
article.nlp()

# %%
article.summary
# Out:
# '"This will reduce the regime\'s ability to further attack the people of Syria with chemical weapons," Stoltenberg said.\nTrump says U.S., allies will launch "precision strikes" until the Syrian government stops the use of chemical weapons.\n0:54Pentagon officials say the attacks were aimed at Assad\'s programs to develop and produce chemical weapons.\nFrance\'s foreign minister is threatening further missile strikes against Syria if the Syrian government uses chemical weapons again.\n"We will continue to work with our international partners to further investigate the use of chemical weapons in Syria.'

# %%
import newspaper

cnn_paper = newspaper.build('http://cbc.ca/news')

for article in cnn_paper.articles:
    print(article.url)

# %%
for category in cnn_paper.category_urls():
    print(category)

# %%
cnn_article = cnn_paper.articles[6]
cnn_article.download()
cnn_article.parse()
cnn_article.nlp()
cnn_article.keywords
# Out:
# ['spoken',
#  'potconsumption',
#  'marijuana',
#  'manitoba',
#  'weedonce',
#  'pot',
#  'buy',
#  'youll',
#  'market',
#  'depends',
#  'recreational']

# %%
cnn_article.summary
# Out:
# "How will Manitobans buy their pot?\nThat depends on what you want in your weedOnce recreational cannabis use is legalized, where and how you'll buy it largely depends on what you want from your pot-consumption experience, according to people CBC News has spoken with who all hope to be part of Manitoba's marijuana market."

# %%
cnn_article.html
# Out:
# '\n        <!DOCTYPE html>\n        <html lang="en">\n            <head>\n                <title data-react-helmet="true">Manitoba - CBC News</title>\n                <meta charset="utf-8" />\n                <meta name="viewport" content="width=device-width, initial-scale=1" />\n                <link rel="manifest" href="/a/manifest.json" />\n                <link rel="apple-touch-icon" href="/a/apple-touch-icon.png" />\n                <link rel="icon" type="image/x-icon" href="/a/favicon.ico" />\n                <link type="text/css" href="/a/styles/main.css" rel="stylesheet" />\n                <link data-react-helmet="true" rel="canonical" href="http://www.cbc.ca/news/canada/manitoba"/>\n                \n                <meta data-react-helmet="true" property="og:site_name" content="CBC"/><meta data-react-helmet="true" property="fb:pages" content="185669354938012,48363581912,980153248675210,50566954493,262275773829225,630185150356988,82184406949,564980490362398,9021636963,5823419603,325135839870,192209947577094,234303596639900"/><meta data-react-helmet="true" property="og:url" content="http://www.cbc.ca/news/canada/manitoba"/><meta data-react-helmet="true" property="og:title" content="Manitoba - CBC News"/><meta data-react-helmet="true" property="og:description" content="Stay on top of Manitoba with the latest in news, weather, events and interviews."/><meta data-react-helmet="true" property="og:locale" content="en_US"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" name="google-site-verification" content="pJy_QmRvDz2tr7X8eQ6Y1L3Se-8RWM_PpJX42Pr_fYo"/><meta data-react-helmet="true" name="twitter:site" content="@cbc"/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="description" content="Stay on top of Manitoba with the latest in news, weather, events and interviews."/>\n            </head>\n            <body class="feed">\n                <script id="initialStateDom">window.__INITIAL_STATE__={"trending":{"sections":{}},"content":{"list":[{"imageAspects":"16x9_940,16x9_300,16x9_620,original_620,original_300,16x9tight_140,16x9_460","departments":{"sectionLabels":["News","Canada","Manitoba"],"sectionList":["news","canada","manitoba"]},"author":{"name":"Kim Kaschor","image":"https:\\u002F\\u002Fi.cbc.ca\\u002F1.4288816.1505345374!\\u002FfileImage\\u002FhttpImage\\u002Fimage.jpg_gen\\u002Fderivatives\\u002Fsquare_140\\u002Fkim-kaschor.jpg"},"slug":"manitoba-marijuana-retail","external":false,"flag":"","itemType":"story","relatedLinks":[{"url":"http:\\u002F\\u002Fwww.cbc.ca\\u002Fnews\\u002Fpolitics\\u002Fsenate-vote-pot-bill-1.4537624","title":"Senate deal on cannabis bill timeline means no sales before August","sourceId":"1.4537624"},{"url":"http:\\u002F\\u002Fwww.cbc.ca\\u002Fnews\\u002Fcanada\\u002Fmanitoba\\u002Fpembina-valley-marijuana-legalization-1.4453139","title":"Many southern Manitoba communities saying \'yes\' to pot","sourceId":"1.4453139"},{"url":"http:\\u002F\\u002Fwww.cbc.ca\\u002Fnews\\u002Fcanada\\u002Fmanitoba\\u002Flegal-age-buy-pot-manitoba-19-1.4433640","title":"Manitobans will be able to buy pot online, but can\'t grow at home under new legislation","sourceId":"1.4433640"},{"url":"http:\\u002F\\u002Fwww.cbc.ca\\u002Fnews\\u002Fcanada\\u002Fmanitoba\\u002Fmanitoba-cannabis-legislation-1.4584619","title":"Toking allowed in homes but few other places under proposed Manitoba law","sourceId":"1.4584619"},{"url":"http:\\u002F\\u002Fwww.cbc.ca\\u002Fnews\\u002Fcanada\\u002Fmanitoba\\u002Fretail-cannabis-stores-manitoba-1.4538478","title":"Province promises hands-off approach to cannabis retailers after announcing 4 groups that will operate stores","sourceId":"1.4538478"}],"url":"\\u002Fnews\\u002Fcanada\\u002Fmanitoba\\u002Fmanitoba-marijuana-retail-1.4618426","imageURL":"https:\\u002F\\u002Fi.cbc.ca\\u002F1.3282584.1523644252!\\u002FcpImage\\u002FhttpImage\\u002Fimage.jpg_gen\\u002Fderiva ...
